# %%
import mne
import time
import scipy.signal
import numpy                as     np 
import matplotlib.animation as     animation
import matplotlib.pyplot    as     plt
from   joblib               import Parallel, delayed

# %%
def smooth_spectra(spectra, win_time, win_freq, fft=False):
    kernel = np.ones([1,win_freq, win_time])
    if fft == True:
        return scipy.signal.fftconvolve(spectra, kernel, mode='same', axes=(1,2))
    else:
        return scipy.signal.convolve2d(spectra, kernel, mode='same', axes = (1,2))

# %%
#####################################################################################################
# Loading session data
#####################################################################################################
session_data = np.load('raw_lfp/lucy_session01_150128.npy', allow_pickle=True).item()
LFP          = session_data['data']
fsample      = int(session_data['info']['fsample'])
T,C,N        = LFP.shape
pairs        = session_data['info']['pairs']

freqs = np.arange(4,60,1)

W_ml = mne.time_frequency.tfr_array_morlet(LFP, fsample, freqs, n_cycles=freqs/2.0, zero_mean=False, 
                                           use_fft=True, decim=15, output='complex', n_jobs=-1, verbose=None)

#W_mt = mne.time_frequency.tfr_array_multitaper(LFP, fsample, freqs, n_cycles=5.0, zero_mean=False, 
#                                               time_bandwidth=None, use_fft=True, decim=15, output='complex', 
#                                               n_jobs=-1, verbose=None)
# Out:
# [Parallel(n_jobs=40)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done  20 out of  49 | elapsed:   25.6s remaining:   37.2s
# [Parallel(n_jobs=40)]: Done  30 out of  49 | elapsed:   27.8s remaining:   17.6s
# [Parallel(n_jobs=40)]: Done  40 out of  49 | elapsed:   30.1s remaining:    6.8s
# [Parallel(n_jobs=40)]: Done  49 out of  49 | elapsed:   33.5s finished

# %%
print('Tensor dimensions = ' + str(W_ml.shape))
# Out:
# Tensor dimensions = (540, 49, 56, 244)

# %%
# Auto-spectra
S_auto = W_ml * np.conj(W_ml)#np.einsum('ijkw,ijkw->ijkw', W_ml, np.conj(W_ml))#

# %%
print('Tensor dimensions = ' + str(S_auto.shape))
# Out:
# Tensor dimensions = (540, 49, 56, 244)

# %%
plt.imshow(S_auto[0,10,:,:].real, aspect = 'auto', cmap = 'jet', origin = 'lower'); plt.colorbar()

# %%
S_smooth = smooth_spectra(S_auto[0,10,:,:].T.real, 34, 5, fft=True)
plt.imshow(S_smooth.T, aspect = 'auto', cmap = 'jet', origin = 'lower'); plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-780da1e83316> in <module>
# ----> 1 S_smooth = smooth_spectra(S_auto[0,10,:,:].T.real, 34, 5, fft=True)
#       2 plt.imshow(S_smooth.T, aspect = 'auto', cmap = 'jet', origin = 'lower'); plt.colorbar()
#
# <ipython-input-12-61e7ff1f1bb2> in smooth_spectra(spectra, win_time, win_freq, fft)
#       2     kernel = np.ones([win_time, win_freq])
#       3     if fft == True:
# ----> 4         return scipy.signal.fftconvolve(spectra, kernel, mode='same', axes = (1,2))
#       5     else:
#       6         return scipy.signal.convolve2d(spectra, kernel, mode='same', axes = (1,2))
#
# /opt/ohpc/pub/libs/gnu8/python/3.6.6/lib64/python3.6/site-packages/scipy/signal/signaltools.py in fftconvolve(in1, in2, mode, axes)
#     376         return array([])
#     377
# --> 378     _, axes = _init_nd_shape_and_axes_sorted(in1, shape=None, axes=axes)
#     379
#     380     if not noaxes and not axes.size:
#
# /opt/ohpc/pub/libs/gnu8/python/3.6.6/lib64/python3.6/site-packages/scipy/fftpack/helper.py in _init_nd_shape_and_axes_sorted(x, shape, axes)
#     269     """
#     270     noaxes = axes is None
# --> 271     shape, axes = _init_nd_shape_and_axes(x, shape, axes)
#     272
#     273     if not noaxes:
#
# /opt/ohpc/pub/libs/gnu8/python/3.6.6/lib64/python3.6/site-packages/scipy/fftpack/helper.py in _init_nd_shape_and_axes(x, shape, axes)
#     205
#     206     if axes.size != 0 and (axes.max() >= x.ndim or axes.min() < 0):
# --> 207         raise ValueError("axes exceeds dimensionality of input")
#     208     if axes.size != 0 and unique(axes).shape != axes.shape:
#     209         raise ValueError("all axes must be unique")
#
# ValueError: axes exceeds dimensionality of input

# %%
def pairwise_coherence(index_pair, win_time, win_freq):
    channel1, channel2 = pairs[index_pair,0], pairs[index_pair,1]
    Sxy = W_ml[:, channel1, :, :] * np.conj(W_ml[:, channel2, :, :])
    #print(Sxy.shape)
    Sxx = smooth_spectra(S_auto[:,channel1, :, :], win_time, win_freq, fft=True)
    #print(Sxy.shape)
    Syy = smooth_spectra(S_auto[:,channel2, :, :], win_time, win_freq, fft=True)
    Sxy = smooth_spectra(Sxy, win_time, win_freq, fft=True)
    return Sxy * np.conj(Sxy) / (Sxx * Syy )

# %%
start = time.time()
coh = pairwise_coherence(454, 34, 5)
end = time.time()

print('Elapsed time to load super-tensor: ' +str((end - start)) + ' sec.' )
# Out:
# Elapsed time to load super-tensor: 4.671844482421875 sec.

# %%
plt.imshow(coh[0,:,:].real, aspect = 'auto', cmap = 'jet', origin = 'lower'); plt.colorbar()

# %%
start = time.time()

Parallel(n_jobs=-1,  prefer="threads", backend='loky', timeout=1e6)(
        delayed(pairwise_coherence)(index_pair, 34, 5)
                for index_pair in range(pairs.shape[0]) )

end = time.time()

print('Elapsed time to load super-tensor: ' +str((end - start)/1) + ' sec.' )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-2b1e5a63b01a> in <module>
#       3 Parallel(n_jobs=-1,  prefer="threads", backend='loky', timeout=1e6)(
#       4         delayed(pairwise_coherence)(index_pair, 34, 5)
# ----> 5                 for index_pair in range(pairs.shape[0]) )
#       6
#       7 end = time.time()
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib64/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib64/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
np.array(coh).shape
# Out:
# (1176, 56, 244)

# %%
plt.imshow(np.array(coh)[454,:,:].real, aspect = 'auto', cmap = 'jet', origin = 'lower'); plt.colorbar()

# %%
session_data.keys()
# Out:
# dict_keys(['data', 'info', 'path'])

# %%
index_pair = 454
pairs[index_pair,0], pairs[index_pair,1]
# Out:
# (10, 30)

# %%
pairs
# Out:
# array([[ 0,  1],
#        [ 0,  2],
#        [ 0,  3],
#        ...,
#        [46, 47],
#        [46, 48],
#        [47, 48]])

# %%
W_ml.shape
# Out:
# (540, 49, 56, 244)

# %%
Sxy = W_ml[:,pairs[:,0], :,:] * np.conj(W_ml[0,pairs[:,1], :,:])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-a50168a0037b> in <module>
# ----> 1 Sxy = W_ml[:,pairs[:,0], :,:] * np.conj(W_ml[0,pairs[:,1], :,:])
#
# MemoryError:

# %%
[540,1176,59,44]
# Out:
# array([[ 0,  1],
#        [ 0,  2],
#        [ 0,  3],
#        ...,
#        [46, 47],
#        [46, 48],
#        [47, 48]])

# %%
W_ml.shape
# Out:
# (540, 49, 28, 244)

# %%
np.zeros([540,1176,56,244])

# %%
coh.shape
# Out:
# (540, 28, 244)

# %%
plt.imshow(coh[0,:,:].real, aspect='auto', cmap="jet");plt.colorbar()
